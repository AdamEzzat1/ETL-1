# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Generate a large random dataset
#rs = np.random.RandomState(33)
#d = pd.DataFrame(data=rs.normal(size=(100, 26)),
                 #columns=list(ascii_letters[26:]))
    

# Compute the correlation matrix
#corr = d.corr()
KBB_df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-81f738ad2f4e> in <module>
#      15 # Compute the correlation matrix
#      16 #corr = d.corr()
# ---> 17 KBB_df.corr()
#      18
#      19 # Generate a mask for the upper triangle
#
# NameError: name 'KBB_df' is not defined

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
KBB_df.corr()
# Out:
#                                  kms driven  depreciation      year  \
# kms driven                         1.000000     -0.057835 -0.175858
# depreciation                      -0.057835      1.000000  0.219860
# year                              -0.175858      0.219860  1.000000
# years since new                    0.175858     -0.219860 -1.000000
# Expert-Rating                     -0.003998     -0.097830 -0.336922
# Consumer-Rating                   -0.168629     -0.058513  0.155103
# SafetyRating                       0.049520     -0.079718 -0.280677
# Years_since_new                         NaN           NaN       NaN
# Bluetooth Wireless Technology     -0.108066      0.205226  0.722873
# Cruise Control                     0.063910     -0.003417 -0.524137
# Hands Free Phone                  -0.107394      0.177110  0.539083
# Navigation System                  0.041943      0.050603 -0.317572
# Remote Keyless Entry              -0.068656      0.190680  0.417637
# ...

# %%
plt.figure(figsize=(44,44))
sns.heatmap(KBB_df.corr(), annot=True, cmap='coolwarm', annot_kws={"fontsize":20} )
sns.set(font_scale=2) # font size 2
#depreciation and year
#depreciation and Bluetooth Wireless Technology 
#depreciation and Push-Buttion Engine Start
#depreciation and Remote Engine Start
#depreciation and Real-Time Traffic Information
#depreciation and 
#depreciation and

# %%
x, y = np.random.multivariate_normal(mean, cov, 1000).T
with sns.axes_style("white"):
    sns.jointplot(x=x, y=y, kind="hex", color="k");

# %%
KBB_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1237 entries, 0 to 1236
# Data columns (total 44 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   brand                            1237 non-null   object
#  1   condition                        1237 non-null   object
#  2   fuel                             1237 non-null   object
#  3   kms driven                       1237 non-null   int64
#  4   model                            1237 non-null   object
#  5    price in USD                    1237 non-null   object
#  6    price                           1237 non-null   object
#  7   depreciation                     1237 non-null   float64
#  8   registered city                  988 non-null    object
#  9   transaction type                 1237 non-null   object
#  10  year                             1237 non-null   int64
#  11  years since new                  1237 non-null   int64
# ...

# %%
KBB_depreciation = KBB_df.groupby('depreciation').mean()[['years since new']]

# %%
KBB_depreciation.plot.line()

# %%
KBB_depreciation_1 = KBB_df.groupby('year').mean()[['Bluetooth Wireless Technology',  'Remote Engine Start', 'Real-Time Traffic Information']]
#depreciation and year
#depreciation and Bluetooth Wireless Technology 
#depreciation and Push-Buttion Engine Start
#depreciation and Remote Engine Start
#depreciation and Real-Time Traffic Information
#depreciation and 
#depreciation and

# %%
KBB_depreciation_1.plot.line()

# %%
sns.jointplot(x="Real-Time Traffic Information", y="depreciation", data=KBB_df);

# %%
KBB_df.plot.scatter(x='depreciation', y='years since new')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
KBB_df.plot.scatter(x='depreciation', y='year')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
KBB_df.plot.hexbin(x='depreciation', y='years since new', gridsize=15)

# %%
sns.distplot(KBB_df['year'])
plt.show()

# %%
del KBB_df['Unnamed: 0']

# %%
del KBB_df['Unnamed: 0.1']

# %%
del KBB_df['Unnamed: 0.1.1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 0.1.1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-9aff0bba189d> in <module>
# ----> 1 del KBB_df['Unnamed: 0.1.1']
#
# ...

# %%
del KBB_df['Unnamed: 0.1.1.1']

# %%
del KBB_df['Maker']

# %%
del KBB_df['Year']

# %%
del KBB_df['Model']

# %%
KBB_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c3f62da069bf> in <module>
# ----> 1 KBB_df
#
# NameError: name 'KBB_df' is not defined

# %%
KBB_df
# Out:
#         brand condition    fuel  kms driven   model  price in USD   \
# 0      toyota      used  petrol       39000   yaris     $9,252.67
# 1      toyota       new  petrol       42000   yaris     $9,058.56
# 2      toyota       new  petrol       55000   yaris    $10,352.64
# 3      toyota       new  petrol       25000   yaris    $10,514.40
# 4      toyota      used  petrol       64000   yaris     $8,540.93
# ...       ...       ...     ...         ...     ...            ...
# 1232     audi      used  petrol        9800      a3     $3,235.20
# 1233  hyundai      used     cng        6500  sonata     $1,164.67
# 1234   toyota      used  petrol      189000    rav4    $10,934.97
# 1235   toyota      used  petrol      189000    rav4    $10,934.97
# 1236    honda      used  petrol      156000    cr-v    $10,999.68
#
#                price   depreciation registered city     transaction type  ...  \
# 0      $1,430,000.00       0.611141         karachi                 cash  ...
# ...

# %%
KBB_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1237 entries, 0 to 1236
# Data columns (total 44 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   brand                            1237 non-null   object
#  1   condition                        1237 non-null   object
#  2   fuel                             1237 non-null   object
#  3   kms driven                       1237 non-null   int64
#  4   model                            1237 non-null   object
#  5    price in USD                    1237 non-null   object
#  6    price                           1237 non-null   object
#  7   depreciation                     1237 non-null   float64
#  8   registered city                  988 non-null    object
#  9   transaction type                 1237 non-null   object
#  10  year                             1237 non-null   int64
#  11  years since new                  1237 non-null   int64
# ...

# %%
KBB_df['depreciation'] =  KBB_df['price'] / KBB_df['New_Price']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...

# %%
import pandas as pd
KBB_df = pd.read_csv('KBB_df.csv')

# %%
KBB_df
# Out:
#       Unnamed: 0    brand condition    fuel  kms driven   model  \
# 0              0   toyota      used  petrol       39000   yaris
# 1              1   toyota       new  petrol       42000   yaris
# 2              2   toyota       new  petrol       55000   yaris
# 3              3   toyota       new  petrol       25000   yaris
# 4              4   toyota      used  petrol       64000   yaris
# ...          ...      ...       ...     ...         ...     ...
# 1232        1232     audi      used  petrol        9800      a3
# 1233        1233  hyundai      used     cng        6500  sonata
# 1234        1234   toyota      used  petrol      189000    rav4
# 1235        1235   toyota      used  petrol      189000    rav4
# 1236        1236    honda      used  petrol      156000    cr-v
#
#       price in USD            price   depreciation registered city  ...  \
# 0        $9,252.67    $1,430,000.00       0.611141         karachi  ...
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

sns.set(color_codes=True)

x = np.random.normal(size=100)
sns.distplot(x);
